# %% [markdown]
# # Logan Marshall

# %% [markdown]
# ## **Which countries develop the most NHL prospects?**
#
# Briefly describe your research question or interests here.

# %% [markdown]
# To obtain the necessary data to answer this question, I will need to wrangle and sort the dataset by countries. Then, I will be able to determine the number of prospects that have transferred from each country into the NHL. Then I have the ability to confirm which nation produces the most NHL prospects. I may have to create a "Other" variable to organize my plots. Most Nation's number of players drafted do not compare to Canada or USA, therefore the graph often looks distorted or difficult to observe.

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/NHLDraft.csv")
df.head()
# Out:
#    id  year  overall_pick                 team            player nationality  \
# 0   1  2022             1   Montreal Canadiens  Juraj Slafkovsky          SK
# 1   2  2022             2    New Jersey Devils       Simon Nemec          SK
# 2   3  2022             3      Arizona Coyotes      Logan Cooley          US
# 3   4  2022             4       Seattle Kraken      Shane Wright          CA
# 4   5  2022             5  Philadelphia Flyers   Cutter Gauthier          SE
#
#   position   age  to_year                           amateur_team  ...  points  \
# 0       LW  18.0      NaN                          TPS (Finland)  ...     NaN
# 1        D  18.0      NaN                    HK Nitra (Slovakia)  ...     NaN
# 2        C  18.0      NaN  USA U-18 Development Team (USDP/USHL)  ...     NaN
# 3        C  18.0      NaN              Kingston Frontenacs (OHL)  ...     NaN
# 4       LW  18.0      NaN  USA U-18 Development Team (USDP/USHL)  ...     NaN
#
# ...

# %%
df['nationality'].unique()
# Out:
# array(['SK', 'US', 'CA', 'SE', 'CZ', 'AT', 'RU', 'FI', 'CH', 'DE', 'LV',
#        'PL', 'BY', 'GB', 'KZ', 'NO', 'UA', 'UZ', 'DK', 'AU', 'TH', 'JM',
#        'FR', 'SI', 'BE', 'NL', 'CN', 'LT', nan, 'IT', 'NG', 'EE', 'JP',
#        'ME', 'HU', 'YU', 'BS', 'BR', 'TZ', 'BN', 'KR', 'ZA', 'SU', 'HT',
#        'TW', 'PY', 'VE'], dtype=object)

# %%
countries = {'US': 'USA', 'CA': 'Canada', 'SE': 'Sweden','SK': 'Slovakia', 'AT': 'Austria', 'RU': 'Russia', 'FI': 'Finland', 'CH': 'Switzerland',
'CZ': 'Czechia', 'DE': 'Germany', 'LV': 'Latvia', 'PL': 'Poland', 'BY': 'Belarus', 'GB': 'Great Britain', 'KZ': 'Kazakhstan',
'NO': 'Norway', 'UA': 'Ukraine', 'UZ': 'Uzbekistan' , 'DK': 'Denmark', 'AU': 'Australia', 'TH': 'Thailand' , 'JM': 'Jamacia',
'FR': 'France', 'SI': 'Slovenia', 'BE': 'Belgium', 'NL': 'Netherlands', 'CN': 'China', 'LT': 'Lithuania', 'IT': 'Italy',
'NG': 'Nigeria', 'EE': 'Estonia', 'JP': 'Japan', 'ME': 'Serbia', 'HU': 'Hungary', 'YU': 'Yugoslavia', 'BS': 'Bahamas', 'BR': 'Brazil',
'TZ': 'Tanzania', 'BN': 'Brunei', 'KR': 'South Korea', 'ZA': 'South Africa', 'SU': 'Soviet Union', 'HT': 'Haiti',
'TW': 'Taiwan', 'PY': 'Paraguay', 'VE': 'Venezuela'}
#countries.values()

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import os
sns.set_theme(style="ticks",
              font_scale=1.3, 
             )
import matplotlib.pyplot as plt
plt.rc("axes.spines", top=False, right=False)

# %%
sns.countplot(y='nationality', data = df, order=['CA', 'US', 'SE', 'RU', 'FI', 'CZ', 'SK', 'DE', 'CH', 'LV',
'UA','BY','DK', 'KZ', 'NO', 'GB','AT','Other']).set(xlim=(0,None), ylabel="Nationality",xlabel="Number of Drafted Players")
plt.legend(labels=["Canada","USA","Sweden","Russia","Czechia","Slovakia","Denmark","Germany","Latvia",
           "Ukraine","Belarus","Denmark","Kazakhstan","Norway","Great Britain","Austria", "Other"],
           loc='upper right', bbox_to_anchor=(1.3, 1.05))
#Other = pd.DataFrame()
#Other = df[df['nationality'] == ['PL', 'UZ', 'AU', 'TH', 'JM','FR', 'SI', 'BE', 'NL', 'CN', 'LT', 'IT', 'NG', 'EE', 'JP', 'ME', 'HU', 'YU', 'BS', 'BR', 'TZ', 'BN', 'KR', 'ZA', 'SU', 'HT', 'TW', 'PY', 'VE']]

# %% [markdown]
# Since Canada and USA have a such a significant amount of players that it makes other nationalities appear to have no value, I decided to make this countplot again but lower the max x axis limit.

# %%
plt.figure(figsize=(10,15))
#y_pos = np.arange(len(countries.values()))
sns.countplot(y='nationality', data = df, order=(df['nationality'].value_counts().index)).set(xlim=(0,100), ylabel="Nationality",xlabel="Number of Drafted Players")
#plt.Axes.set_yticks(labels=countries.values())
plt.legend(["Canada","USA", "Sweden", "Russia", "Finland", "Czechia", "Switzerland","Germany", "Latvia", "Ukraine", "Belarus", "Denmark", "Kazakhstan", "Norway","Great Britain","Austria", "France",
           "Slovenia", "Poland", "Hungary", "Uzbekistan", "Yugoslavia", "Lithuania", "Japan", "Italy", "Brazil",
            "Belgium", "Bahamas", "South Korea", "Nigeria", "Estonia", "Soviet Union", "Australia", "Haiti",
           "Taiwan", "Paraguay", "South Africa", "Serbia", "Brunei", "Tanzania", "Thailand", "China", "Netherlands",
           "Jamacia", "Venezuela"], loc='upper right', bbox_to_anchor=(1.3, 1.02))

# %% [markdown]
# I chose this data analysis because it displays clearly that Canada, Usa, Sweden, and Russia develop the most NHL draft prospects.
#
# There is a drastic drop off after Czechia for drafted players.
#
# I can conclude that Canada, Usa, Sweden, Russia, Finland, and Czechia are NHL's main providers for young hockey players. In other words, there a six fully developed hockey countries, while the rest of the world is still implementing or growing the sport of Hockey.

# %%
#SK = Slovakia, US = USA, CA = Canada, SE = Sweden, AT = Austria, RU = Russia, FI = Finland, CH = Switzerland
#CZ = Czechia, DE = Germany, LV = Latvia, PL = Poland < 10, BY = Belarus, GB = Great Britain, KZ = Kazakhstan
#NO = Norway, UA = Ukraine, UZ = Uzbekistan <10, DK = Denmark, AU = Australia <10, TH = Thailand <10, JM = Jamacia<10
#FR = France <10, SI = Slovenia <10, BE = Belgium <10, NL = Netherlands <10, CN = China <10, LT = Lithuania<10, IT = Italy<10
#NG = Nigeria <10, EE = Estonia<10, JP = Japan<10, ME = Serbia <10, HU = Hungary <10, YU = Yugoslavia <10, BS = Bahamas<10, BR = Brazil<10
#TZ = Tanzania <10, BN = Brunei <10, KR = South Korea <10, ZA = South Africa<10, SU = Soviet Union<10, HT = Haiti <10
#TW = Taiwan <10, PY = Paraguay <10, VE = Venezuela <10
sns.histplot(df, x='year', hue='nationality', multiple='stack', legend=False).set(xlim=(1963, 2022), xlabel="Year",ylabel="Number of Drafted Players", title="Nationality of Drafted Players Over the Years")
plt.legend(['Slovakia', 'USA', 'Canada', 'Sweden', 'Czechia', 'Austria', 'Russia', 'Finland', 'Switzerland', 'Germany', 'Latvia',
       'Poland', 'Belarus', 'Great Britain', 'Kazakhstan', 'Norway', 'Ukraine', 'Uzbekistan', 'Denmark', 'Austria', 'Thailand', 'Jamacia',
       'France', 'Slovenia', 'Belgium', 'Netherlands', 'China', 'Lithuania', 'Italy', 'Nigeria', 'Estonia', 'Japan',
       'Serbia', 'Hungary', 'Yugoslavia', 'Bahamas', 'Brazil', 'Tanzania', 'Brunei', 'South Korea', 'South Africa', 'Soviet Union', 'Haiti',
       'Taiwan', 'Paraguay', 'Venezuela'],loc='upper right', bbox_to_anchor=(1.5, 1.4), fontsize='xx-small', labelspacing=0.15)

# %% [markdown]
# I chose the histplot because it presents the growth of hockey around the world.
# Initally, you can only notice two colours (USA and Canada), which means majority of the drafted players were from United States or Canada. However, as the years progressed and the game of hockey grew worldwide, more European players received more recognition and were drafted. You can see in the latest draft years that there is a variety of colours involved in the stack. Which means prospects from numerous countries were drafted.

# %%
fig = plt.figure(figsize=(15,12))
#sns.violinplot(x='year', y='nationality', data=df, order=df['nationality'].value_counts().index)
sns.stripplot(data=df, x='year', y='nationality', order=df['nationality'].value_counts().index, jitter=False)
plt.xlim(1963,2022)
plt.title("Relationship Between a Nationality Having a Draft Prospect in Each Year")
plt.xlabel("Year")
plt.ylabel("Nationality")
# Out:
# Text(0, 0.5, 'Nationality')

# %% [markdown]
# I chose this plot because it specifys which years each country had a representative at the draft. This plot also clarifys that USA and Canada were the main providers for draft prospects in the early years (1960s). Then, you can notice more Swedish and Russian players were being scouted starting in the mid 1970s. Once we reached the 1990s, there was multiple countries that had a representative at the NHL drafts.
