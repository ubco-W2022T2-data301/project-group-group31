# %% [markdown]
# # Logan Marshall

# %% [markdown]
# ## **Which countries or junior leagues develop the most NHL prospects?**
#
# Briefly describe your research question or interests here.

# %% [markdown]
# To obtain the necessary data to answer this question, we will need to wrangle and sort the dataset by leagues or countries. Then, I will be able to determine the number of prospects that transferred from each junior league or country into the NHL. Then I have the ability to confirm which league or country produces the most NHL prospects.

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/NHLDraft.csv")
df
# Out:
#           id  year  overall_pick                 team            player  \
# 0          1  2022             1   Montreal Canadiens  Juraj Slafkovsky
# 1          2  2022             2    New Jersey Devils       Simon Nemec
# 2          3  2022             3      Arizona Coyotes      Logan Cooley
# 3          4  2022             4       Seattle Kraken      Shane Wright
# 4          5  2022             5  Philadelphia Flyers   Cutter Gauthier
# ...      ...   ...           ...                  ...               ...
# 12245  12246  1963            17  Toronto Maple Leafs       Jim McKenny
# 12246  12247  1963            18   Montreal Canadiens      Glen Shirton
# 12247  12248  1963            19        Boston Bruins         Jim Blair
# 12248  12249  1963            20     New York Rangers  Campbell Alleson
# 12249  12250  1963            21  Toronto Maple Leafs      Gerry Meehan
#
#       nationality position   age  to_year  \
# 0              SK       LW  18.0      NaN
# 1              SK        D  18.0      NaN
# 2              US        C  18.0      NaN
# 3              CA        C  18.0      NaN
# 4              SE       LW  18.0      NaN
# ...           ...      ...   ...      ...
# 12245          CA        D  16.0   1979.0
# 12246          CA        D   NaN      NaN
# 12247          CA        F   NaN      NaN
# 12248          CA        D   NaN      NaN
# 12249          CA        C  17.0   1979.0
#
#                                 amateur_team  ...  points  plus_minus  \
# 0                              TPS (Finland)  ...     NaN         NaN
# 1                        HK Nitra (Slovakia)  ...     NaN         NaN
# 2      USA U-18 Development Team (USDP/USHL)  ...     NaN         NaN
# 3                  Kingston Frontenacs (OHL)  ...     NaN         NaN
# 4      USA U-18 Development Team (USDP/USHL)  ...     NaN         NaN
# ...                                      ...  ...     ...         ...
# 12245  Toronto Neil McNeil Maroons (MetJAHL)  ...   329.0        -4.0
# 12246               Port Colborne Midgets ()  ...     NaN         NaN
# 12247           Georgetown Midgets (OHA-Jr.)  ...     NaN         NaN
# 12248              Portage la Prairie Jr. ()  ...     NaN         NaN
# 12249  Toronto Neil McNeil Maroons (MetJAHL)  ...   423.0      -113.0
#
#        penalties_minutes  goalie_games_played  goalie_wins  goalie_losses  \
# 0                    NaN                  NaN          NaN            NaN
# 1                    NaN                  NaN          NaN            NaN
# 2                    NaN                  NaN          NaN            NaN
# 3                    NaN                  NaN          NaN            NaN
# 4                    NaN                  NaN          NaN            NaN
# ...                  ...                  ...          ...            ...
# 12245              294.0                  NaN          NaN            NaN
# 12246                NaN                  NaN          NaN            NaN
# 12247                NaN                  NaN          NaN            NaN
# 12248                NaN                  NaN          NaN            NaN
# 12249              111.0                  NaN          NaN            NaN
#
#        goalie_ties_overtime  save_percentage  goals_against_average  \
# 0                       NaN              NaN                    NaN
# 1                       NaN              NaN                    NaN
# 2                       NaN              NaN                    NaN
# 3                       NaN              NaN                    NaN
# 4                       NaN              NaN                    NaN
# ...                     ...              ...                    ...
# 12245                   NaN              NaN                    NaN
# 12246                   NaN              NaN                    NaN
# 12247                   NaN              NaN                    NaN
# 12248                   NaN              NaN                    NaN
# 12249                   NaN              NaN                    NaN
#
#        point_shares
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 12245          53.7
# 12246           NaN
# 12247           NaN
# 12248           NaN
# 12249          30.5
#
# [12250 rows x 23 columns]

# %%
df['nationality'].unique()
# Out:
# array(['SK', 'US', 'CA', 'SE', 'CZ', 'AT', 'RU', 'FI', 'CH', 'DE', 'LV',
#        'PL', 'BY', 'GB', 'KZ', 'NO', 'UA', 'UZ', 'DK', 'AU', 'TH', 'JM',
#        'FR', 'SI', 'BE', 'NL', 'CN', 'LT', nan, 'IT', 'NG', 'EE', 'JP',
#        'ME', 'HU', 'YU', 'BS', 'BR', 'TZ', 'BN', 'KR', 'ZA', 'SU', 'HT',
#        'TW', 'PY', 'VE'], dtype=object)

# %%
#SK = Slovakia, US = USA, CA = Canada, SE = Sweden, AT = Austria, RU = Russia, FI = Finland, CH = Switzerland
#CZ = Czechia, DE = Germany, LV = Latvia, PL = Poland < 10, BY = Belarus, GB = Great Britain, KZ = Kazakhstan
#NO = Norway, UA = Ukraine, UZ = Uzbekistan <10, DK = Denmark, AU = Australia <10, TH = Thailand <10, JM = Jamacia<10
#FR = France <10, SI = Slovenia <10, BE = Belgium <10, NL = Netherlands <10, CN = China <10, LT = Lithuania<10, IT = Italy<10
#NG = Nigeria<10, EE = Estonia<10, JP = Japan<10, ME = Serbia<10, HU = Hungary<10, YU = Yugoslavia<10, BS = Bahamas<10, BR = Brazil<10
#TZ = Tanzania<10, BN = Brunei<10, KR = South Korea<10, ZA = South Africa<10, SU = Soviet Union<10, HT = Haiti<10
#TW = Taiwan<10, PY = Paraguay<10, VE = Venezuela<10

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import os
sns.set_theme(style="ticks",
              font_scale=1.3, # This scales the fonts slightly higher
             )
# And we're going to remove the top and right axis lines
import matplotlib.pyplot as plt
plt.rc("axes.spines", top=False, right=False)

# %%
sns.countplot(y='nationality', data = df, order=['SK', 'US', 'CA', 'SE', 'CZ', 'AT', 'RU', 'FI', 'CH', 'DE', 'LV',
'BY', 'GB', 'KZ', 'NO', 'UA','DK', 'Other']).set(xlim=(0,3000))
#Other = df[df['nationality'] == ['PL', 'UZ', 'AU', 'TH', 'JM','FR', 'SI', 'BE', 'NL', 'CN', 'LT', 'IT', 'NG', 'EE', 'JP', 'ME', 'HU', 'YU', 'BS', 'BR', 'TZ', 'BN', 'KR', 'ZA', 'SU', 'HT', 'TW', 'PY', 'VE']]
# Out:
# [(0.0, 3000.0)]

# %%
sns.histplot(df, x='year', hue='nationality', multiple='stack', legend=False).set(xlim=(1963, 2022))
# Out:
# [(1963.0, 2022.0)]

# %%
sns.set_theme(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})
grid = sns.FacetGrid(df, row='nationality', hue='nationality',aspect=15, height=1)
grid.map(sns.kdeplot, 'year', bw_adjust=.5, clip_on=False, fill=True, alpha=1, linewidth=1.5)
grid.map(sns.kdeplot, 'year', clip_on=False, color="w", lw=2, bw_adjust=.5)
grid.refline(y=0, linewidth=2, linestyle="-", color=None, clip_on=False)

def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .2, label, fontweight="bold", color=color,
            ha="left", va="center", transform=ax.transAxes)
grid.map(label, 'year')
grid.figure.subplots_adjust(hspace=-.25)
grid.set_titles("")
grid.set(yticks=[], ylabel="")
grid.despine(bottom=True, left=True)
grid
# Out:
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# C:\Users\logan\miniconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[132], line 5
#       3 grid.map(sns.kdeplot, 'year', bw_adjust=.5, clip_on=False, fill=True, alpha=1, linewidth=1.5)
#       4 grid.map(sns.kdeplot, 'year', clip_on=False, color="w", lw=2, bw_adjust=.5)
# ----> 5 grid.refline(y=0, linewidth=2, linestyle="-", color=None, clip_on=False)
#       7 def label(x, color, label):
#       8     ax = plt.gca()
#
# File ~\miniconda3\lib\site-packages\seaborn\axisgrid.py:1060, in FacetGrid.refline(self, x, y, color, linestyle, **line_kws)
#    1057     self.map(plt.axvline, x=x, **line_kws)
#    1059 if y is not None:
# -> 1060     self.map(plt.axhline, y=y, **line_kws)
#    1062 return self
#
# File ~\miniconda3\lib\site-packages\seaborn\axisgrid.py:755, in FacetGrid.map(self, func, *args, **kwargs)
#     752     self._facet_plot(func, ax, plot_args, kwargs)
#     754 # Finalize the annotations and layout
# --> 755 self._finalize_grid(args[:2])
#     757 return self
#
# File ~\miniconda3\lib\site-packages\seaborn\axisgrid.py:856, in FacetGrid._finalize_grid(self, axlabels)
#     854 """Finalize the annotations and layout."""
#     855 self.set_axis_labels(*axlabels)
# --> 856 self.tight_layout()
#
# File ~\miniconda3\lib\site-packages\seaborn\axisgrid.py:118, in Grid.tight_layout(self, *args, **kwargs)
#     116 if self._tight_layout_pad is not None:
#     117     kwargs.setdefault("pad", self._tight_layout_pad)
# --> 118 self._figure.tight_layout(*args, **kwargs)
#     119 return self
#
# File ~\miniconda3\lib\site-packages\matplotlib\figure.py:3236, in Figure.tight_layout(self, pad, h_pad, w_pad, rect)
#    3234 renderer = get_renderer(self)
#    3235 with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 3236     kwargs = get_tight_layout_figure(
#    3237         self, self.axes, subplotspec_list, renderer,
#    3238         pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    3239 if kwargs:
#    3240     self.subplots_adjust(**kwargs)
#
# File ~\miniconda3\lib\site-packages\matplotlib\tight_layout.py:347, in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     344     if top is not None:
#     345         top -= (1 - kwargs["top"])
# --> 347     kwargs = _auto_adjust_subplotpars(fig, renderer,
#     348                                       shape=(max_nrows, max_ncols),
#     349                                       span_pairs=span_pairs,
#     350                                       subplot_list=subplot_list,
#     351                                       ax_bbox_list=ax_bbox_list,
#     352                                       pad=pad, h_pad=h_pad, w_pad=w_pad,
#     353                                       rect=(left, bottom, right, top))
#     355 return kwargs
#
# File ~\miniconda3\lib\site-packages\matplotlib\tight_layout.py:82, in _auto_adjust_subplotpars(fig, renderer, shape, span_pairs, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#      80 if ax.get_visible():
#      81     try:
# ---> 82         bb += [ax.get_tightbbox(renderer, for_layout_only=True)]
#      83     except TypeError:
#      84         bb += [ax.get_tightbbox(renderer)]
#
# File ~\miniconda3\lib\site-packages\matplotlib\axes\_base.py:4637, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4635 if self.yaxis.get_visible():
#    4636     try:
# -> 4637         bb_yaxis = self.yaxis.get_tightbbox(
#    4638             renderer, for_layout_only=for_layout_only)
#    4639     except TypeError:
#    4640         # in case downstream library has redefined axis:
#    4641         bb_yaxis = self.yaxis.get_tightbbox(renderer)
#
# File ~\miniconda3\lib\site-packages\matplotlib\axis.py:1105, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1101     return
#    1103 ticks_to_draw = self._update_ticks()
# -> 1105 self._update_label_position(renderer)
#    1107 # go back to just this axis's tick labels
#    1108 ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(
#    1109             ticks_to_draw, renderer)
#
# File ~\miniconda3\lib\site-packages\matplotlib\axis.py:2349, in YAxis._update_label_position(self, renderer)
#    2345     return
#    2347 # get bounding boxes for this axis and any siblings
#    2348 # that have been set by `fig.align_ylabels()`
# -> 2349 bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2350 x, y = self.label.get_position()
#    2351 if self.label_position == 'left':
#
# File ~\miniconda3\lib\site-packages\matplotlib\axis.py:1880, in Axis._get_tick_boxes_siblings(self, renderer)
#    1878 for ax in grouper.get_siblings(self.axes):
#    1879     axis = getattr(ax, f"{axis_name}axis")
# -> 1880     ticks_to_draw = axis._update_ticks()
#    1881     tlb, tlb2 = axis._get_tick_bboxes(ticks_to_draw, renderer)
#    1882     bboxes.extend(tlb)
#
# File ~\miniconda3\lib\site-packages\matplotlib\axis.py:1045, in Axis._update_ticks(self)
#    1040 def _update_ticks(self):
#    1041     """
#    1042     Update ticks (position and labels) using the current data interval of
#    1043     the axes.  Return the list of ticks that will be drawn.
#    1044     """
# -> 1045     major_locs = self.get_majorticklocs()
#    1046     major_labels = self.major.formatter.format_ticks(major_locs)
#    1047     major_ticks = self.get_major_ticks(len(major_locs))
#
# File ~\miniconda3\lib\site-packages\matplotlib\axis.py:1277, in Axis.get_majorticklocs(self)
#    1275 def get_majorticklocs(self):
#    1276     """Return this Axis' major tick locations in data coordinates."""
# -> 1277     return self.major.locator()
#
# File ~\miniconda3\lib\site-packages\matplotlib\ticker.py:2115, in MaxNLocator.__call__(self)
#    2113 def __call__(self):
#    2114     vmin, vmax = self.axis.get_view_interval()
# -> 2115     return self.tick_values(vmin, vmax)
#
# File ~\miniconda3\lib\site-packages\matplotlib\ticker.py:2123, in MaxNLocator.tick_values(self, vmin, vmax)
#    2120     vmin = -vmax
#    2121 vmin, vmax = mtransforms.nonsingular(
#    2122     vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2123 locs = self._raw_ticks(vmin, vmax)
#    2125 prune = self._prune
#    2126 if prune == 'lower':
#
# File ~\miniconda3\lib\site-packages\matplotlib\ticker.py:2062, in MaxNLocator._raw_ticks(self, vmin, vmax)
#    2060 if self._nbins == 'auto':
#    2061     if self.axis is not None:
# -> 2062         nbins = np.clip(self.axis.get_tick_space(),
#    2063                         max(1, self._min_n_ticks - 1), 9)
#    2064     else:
#    2065         nbins = 9
#
# File ~\miniconda3\lib\site-packages\matplotlib\axis.py:2524, in YAxis.get_tick_space(self)
#    2522 def get_tick_space(self):
#    2523     ends = mtransforms.Bbox.from_bounds(0, 0, 1, 1)
# -> 2524     ends = ends.transformed(self.axes.transAxes -
#    2525                             self.figure.dpi_scale_trans)
#    2526     length = ends.height * 72
#    2527     # Having a spacing of at least 2 just looks good.
#
# File ~\miniconda3\lib\site-packages\matplotlib\transforms.py:492, in BboxBase.transformed(self, transform)
#     488 """
#     489 Construct a `Bbox` by statically transforming this one by *transform*.
#     490 """
#     491 pts = self.get_points()
# --> 492 ll, ul, lr = transform.transform(np.array(
#     493     [pts[0], [pts[0, 0], pts[1, 1]], [pts[1, 0], pts[0, 1]]]))
#     494 return Bbox([ll, [lr[0], ul[1]]])
#
# File ~\miniconda3\lib\site-packages\matplotlib\transforms.py:1503, in Transform.transform(self, values)
#    1500 values = values.reshape((-1, self.input_dims))
#    1502 # Transform the values
# -> 1503 res = self.transform_affine(self.transform_non_affine(values))
#    1505 # Convert the result back to the shape of the input values.
#    1506 if ndim == 0:
#
# File ~\miniconda3\lib\site-packages\matplotlib\transforms.py:2419, in CompositeGenericTransform.transform_affine(self, points)
#    2417 def transform_affine(self, points):
#    2418     # docstring inherited
# -> 2419     return self.get_affine().transform(points)
#
# File ~\miniconda3\lib\site-packages\matplotlib\transforms.py:2446, in CompositeGenericTransform.get_affine(self)
#    2444     return self._b.get_affine()
#    2445 else:
# -> 2446     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2447                            self._a.get_affine().get_matrix()))
#
# File ~\miniconda3\lib\site-packages\matplotlib\transforms.py:1914, in Affine2D.__init__(self, matrix, **kwargs)
#    1911 if matrix is None:
#    1912     # A bit faster than np.identity(3).
#    1913     matrix = IdentityTransform._mtx.copy()
# -> 1914 self._mtx = matrix.copy()
#    1915 self._invalid = 0
#
# KeyboardInterrupt:
